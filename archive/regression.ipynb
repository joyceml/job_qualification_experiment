# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('final_dataset.csv')
df
# Out:
#                      id  choiceNum  candNum                       college  \
# 0     R_0GkP9YSiNDMukb7          1        1             Boston University
# 1     R_0GkP9YSiNDMukb7          1        2           Stanford University
# 2     R_0GkP9YSiNDMukb7          2        1             Boston University
# 3     R_0GkP9YSiNDMukb7          2        2                 Virginia Tech
# 4     R_0GkP9YSiNDMukb7          3        1  George Washington University
# ...                 ...        ...      ...                           ...
# 2157  R_zeaJCDw8vld0P73          3        2  George Washington University
# 2158  R_zeaJCDw8vld0P73          4        1                 Virginia Tech
# 2159  R_zeaJCDw8vld0P73          4        2                 Virginia Tech
# 2160  R_zeaJCDw8vld0P73          5        1  George Washington University
# 2161  R_zeaJCDw8vld0P73          5        2             Boston University
#
#       exp                   job  gender ethnicity  filtered  preference  Y  \
# 0     5.0     Software Engineer    Male     White      True           2  0
# 1     7.0  Sales Representative  Female     White      True           2  1
# 2     7.0  Sales Representative    Male       POC     False           1  1
# 3     6.0  Sales Representative    Male       POC      True           1  0
# 4     7.0     Software Engineer    Male     White     False           1  1
# ...   ...                   ...     ...       ...       ...         ... ..
# 2157  7.0  Sales Representative    Male       POC      True           1  0
# 2158  6.0            Consultant    Male     White     False           2  0
# 2159  7.0  Sales Representative    Male     White      True           2  1
# 2160  7.0          Data Analyst    Male       POC     False           1  1
# 2161  6.0            Consultant    Male       POC      True           1  0
#
#                  resp_ethnicity resp_sex         resp_age  \
# 0     Black or African American     Male  35-44 years old
# 1     Black or African American     Male  35-44 years old
# 2     Black or African American     Male  35-44 years old
# 3     Black or African American     Male  35-44 years old
# 4     Black or African American     Male  35-44 years old
# ...                         ...      ...              ...
# 2157                      White     Male  35-44 years old
# 2158                      White     Male  35-44 years old
# 2159                      White     Male  35-44 years old
# 2160                      White     Male  35-44 years old
# 2161                      White     Male  35-44 years old
#
#             resp_education college_binary    job_binary
# 0         Bachelors Degree           1-50   back-facing
# 1         Bachelors Degree           1-50  front-facing
# 2         Bachelors Degree           1-50  front-facing
# 3         Bachelors Degree         50-100  front-facing
# 4         Bachelors Degree         50-100   back-facing
# ...                    ...            ...           ...
# 2157  High School Graduate         50-100  front-facing
# 2158  High School Graduate         50-100  front-facing
# 2159  High School Graduate         50-100  front-facing
# 2160  High School Graduate         50-100   back-facing
# 2161  High School Graduate           1-50  front-facing
#
# [2162 rows x 17 columns]

# %%
results = smf.ols('Y ~ gender + ethnicity + filtered + college_binary + exp + job_binary', data=df).fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     11.61
# Date:                Wed, 06 Apr 2022   Prob (F-statistic):           7.88e-13
# Time:                        21:41:56   Log-Likelihood:                -1534.8
# No. Observations:                2162   AIC:                             3084.
# Df Residuals:                    2155   BIC:                             3123.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.0501      0.083      0.603      0.547      -0.113       0.213
# gender[T.Male]                -0.0440      0.021     -2.071      0.039      -0.086      -0.002
# ethnicity[T.White]             0.0855      0.021      4.032      0.000       0.044       0.127
# filtered[T.True]               0.0115      0.021      0.542      0.588      -0.030       0.053
# college_binary[T.50-100]       0.0125      0.021      0.590      0.556      -0.029       0.054
# job_binary[T.front-facing]    -0.0835      0.021     -3.939      0.000      -0.125      -0.042
# exp                            0.0761      0.013      5.800      0.000       0.050       0.102
# ==============================================================================
# Omnibus:                     8354.283   Durbin-Watson:                   2.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.256
# Skew:                          -0.003   Prob(JB):                     1.28e-69
# Kurtosis:                       1.123   Cond. No.                         49.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
