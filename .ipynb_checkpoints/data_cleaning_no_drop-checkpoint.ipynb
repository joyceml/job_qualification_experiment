# %%
import pandas as pd

# %% [markdown]
# ## Don't delete any rows

# %%
df = pd.read_csv('formatted_data.csv')
df
# Out:
#                      id  choiceNum  candNum  \
# 0     R_0GkP9YSiNDMukb7          1        1
# 1     R_0GkP9YSiNDMukb7          1        2
# 2     R_0GkP9YSiNDMukb7          2        1
# 3     R_0GkP9YSiNDMukb7          2        2
# 4     R_0GkP9YSiNDMukb7          3        1
# ...                 ...        ...      ...
# 4135  R_Zmz2US2dIggx0gp          3        2
# 4136  R_Zmz2US2dIggx0gp          4        1
# 4137  R_Zmz2US2dIggx0gp          4        2
# 4138  R_Zmz2US2dIggx0gp          5        1
# 4139  R_Zmz2US2dIggx0gp          5        2
#
#                                  college  exp                   job  \
# 0                      Boston University  5.0     Software Engineer
# 1                    Stanford University  7.0  Sales Representative
# 2                      Boston University  7.0  Sales Representative
# 3                          Virginia Tech  6.0  Sales Representative
# 4           George Washington University  7.0     Software Engineer
# ...                                  ...  ...                   ...
# 4135                 Stanford University  5.0  Sales Representative
# 4136                       Virginia Tech  5.0            Consultant
# 4137                   Boston University  6.0  Sales Representative
# 4138  University of California, Berkeley  7.0            Consultant
# 4139                       Virginia Tech  5.0          Data Analyst
#
#                                                   photo  preference  Y
# 0     https://berkeley.qualtrics.com/WRQualtricsCont...           2  0
# 1     https://berkeley.qualtrics.com/WRQualtricsCont...           2  1
# 2     https://berkeley.qualtrics.com/WRQualtricsCont...           1  1
# 3     https://berkeley.qualtrics.com/WRQualtricsCont...           1  0
# 4     https://berkeley.qualtrics.com/WRQualtricsCont...           1  1
# ...                                                 ...         ... ..
# 4135  https://berkeley.qualtrics.com/WRQualtricsCont...           1  0
# 4136  https://berkeley.qualtrics.com/WRQualtricsCont...           2  0
# 4137  https://berkeley.qualtrics.com/WRQualtricsCont...           2  1
# 4138  https://berkeley.qualtrics.com/WRQualtricsCont...           2  0
# 4139  https://berkeley.qualtrics.com/WRQualtricsCont...           2  1
#
# [4140 rows x 9 columns]

# %%
#there are 70 null rows
nulls = df[df['photo'].isnull()]
nulls
# Out:
#                      id  choiceNum  candNum college  exp  job photo  \
# 180   R_1DOu3fdZstLn1qp          1        1     NaN  NaN  NaN   NaN
# 181   R_1DOu3fdZstLn1qp          1        2     NaN  NaN  NaN   NaN
# 182   R_1DOu3fdZstLn1qp          2        1     NaN  NaN  NaN   NaN
# 183   R_1DOu3fdZstLn1qp          2        2     NaN  NaN  NaN   NaN
# 184   R_1DOu3fdZstLn1qp          3        1     NaN  NaN  NaN   NaN
# ...                 ...        ...      ...     ...  ...  ...   ...
# 1895  R_2YnXDBfIiXItTxz          3        2     NaN  NaN  NaN   NaN
# 1896  R_2YnXDBfIiXItTxz          4        1     NaN  NaN  NaN   NaN
# 1897  R_2YnXDBfIiXItTxz          4        2     NaN  NaN  NaN   NaN
# 1898  R_2YnXDBfIiXItTxz          5        1     NaN  NaN  NaN   NaN
# 1899  R_2YnXDBfIiXItTxz          5        2     NaN  NaN  NaN   NaN
#
#       preference  Y
# 180            2  0
# 181            2  1
# 182            2  0
# 183            2  1
# 184            2  0
# ...          ... ..
# 1895           1  0
# 1896           2  0
# 1897           2  1
# 1898           1  1
# 1899           1  0
#
# [70 rows x 9 columns]

# %%
#dropped_ids = nulls['id'].unique()
#dropped_ids

# %%
#drop nulls in dataset
df = df[~(df['photo'].isnull())]
df
# Out:
#                      id  choiceNum  candNum  \
# 0     R_0GkP9YSiNDMukb7          1        1
# 1     R_0GkP9YSiNDMukb7          1        2
# 2     R_0GkP9YSiNDMukb7          2        1
# 3     R_0GkP9YSiNDMukb7          2        2
# 4     R_0GkP9YSiNDMukb7          3        1
# ...                 ...        ...      ...
# 4135  R_Zmz2US2dIggx0gp          3        2
# 4136  R_Zmz2US2dIggx0gp          4        1
# 4137  R_Zmz2US2dIggx0gp          4        2
# 4138  R_Zmz2US2dIggx0gp          5        1
# 4139  R_Zmz2US2dIggx0gp          5        2
#
#                                  college  exp                   job  \
# 0                      Boston University  5.0     Software Engineer
# 1                    Stanford University  7.0  Sales Representative
# 2                      Boston University  7.0  Sales Representative
# 3                          Virginia Tech  6.0  Sales Representative
# 4           George Washington University  7.0     Software Engineer
# ...                                  ...  ...                   ...
# 4135                 Stanford University  5.0  Sales Representative
# 4136                       Virginia Tech  5.0            Consultant
# 4137                   Boston University  6.0  Sales Representative
# 4138  University of California, Berkeley  7.0            Consultant
# 4139                       Virginia Tech  5.0          Data Analyst
#
#                                                   photo  preference  Y
# 0     https://berkeley.qualtrics.com/WRQualtricsCont...           2  0
# 1     https://berkeley.qualtrics.com/WRQualtricsCont...           2  1
# 2     https://berkeley.qualtrics.com/WRQualtricsCont...           1  1
# 3     https://berkeley.qualtrics.com/WRQualtricsCont...           1  0
# 4     https://berkeley.qualtrics.com/WRQualtricsCont...           1  1
# ...                                                 ...         ... ..
# 4135  https://berkeley.qualtrics.com/WRQualtricsCont...           1  0
# 4136  https://berkeley.qualtrics.com/WRQualtricsCont...           2  0
# 4137  https://berkeley.qualtrics.com/WRQualtricsCont...           2  1
# 4138  https://berkeley.qualtrics.com/WRQualtricsCont...           2  0
# 4139  https://berkeley.qualtrics.com/WRQualtricsCont...           2  1
#
# [4070 rows x 9 columns]

# %%
##photo tags
photo_mappings = pd.read_csv('photo_mappings.csv')
photo_mappings.columns = photo_mappings.columns.str.lower()
photo_mappings = photo_mappings.drop(columns='name')
photo_mappings
# Out:
#     gender ethnicity  filtered  \
# 0   Female       POC     False
# 1   Female       POC     False
# 2   Female       POC     False
# 3   Female     White     False
# 4   Female     White     False
# 5   Female     White     False
# 6     Male       POC     False
# 7     Male       POC     False
# 8     Male       POC     False
# 9     Male     White     False
# 10    Male     White     False
# 11    Male     White     False
# 12  Female       POC      True
# 13  Female       POC      True
# 14  Female       POC      True
# 15  Female     White      True
# 16  Female     White      True
# 17  Female     White      True
# 18    Male       POC      True
# 19    Male       POC      True
# 20    Male       POC      True
# 21    Male     White      True
# 22    Male     White      True
# 23    Male     White      True
#
#                                                 photo
# 0   https://berkeley.qualtrics.com/WRQualtricsCont...
# 1   https://berkeley.qualtrics.com/WRQualtricsCont...
# 2   https://berkeley.qualtrics.com/WRQualtricsCont...
# 3   https://berkeley.qualtrics.com/WRQualtricsCont...
# 4   https://berkeley.qualtrics.com/WRQualtricsCont...
# 5   https://berkeley.qualtrics.com/WRQualtricsCont...
# 6   https://berkeley.qualtrics.com/WRQualtricsCont...
# 7   https://berkeley.qualtrics.com/WRQualtricsCont...
# 8   https://berkeley.qualtrics.com/WRQualtricsCont...
# 9   https://berkeley.qualtrics.com/WRQualtricsCont...
# 10  https://berkeley.qualtrics.com/WRQualtricsCont...
# 11  https://berkeley.qualtrics.com/WRQualtricsCont...
# 12  https://berkeley.qualtrics.com/WRQualtricsCont...
# 13  https://berkeley.qualtrics.com/WRQualtricsCont...
# 14  https://berkeley.qualtrics.com/WRQualtricsCont...
# 15  https://berkeley.qualtrics.com/WRQualtricsCont...
# 16  https://berkeley.qualtrics.com/WRQualtricsCont...
# 17  https://berkeley.qualtrics.com/WRQualtricsCont...
# 18  https://berkeley.qualtrics.com/WRQualtricsCont...
# 19  https://berkeley.qualtrics.com/WRQualtricsCont...
# 20  https://berkeley.qualtrics.com/WRQualtricsCont...
# 21  https://berkeley.qualtrics.com/WRQualtricsCont...
# 22  https://berkeley.qualtrics.com/WRQualtricsCont...
# 23  https://berkeley.qualtrics.com/WRQualtricsCont...

# %%
#photo_mappings['endings'] = photo_mappings['photo'].str.replace('https://berkeley.qualtrics.com/WRQualtricsControlPanel/Graphic.php?IM=IM_', '', regex=False)
##df['endings'] = df['photo'].str.replace('https://berkeley.qualtrics.com/WRQualtricsControlPanel/Graphic.php?IM=IM_', '', regex=False)

#df['endings'].unique()

# %%
final_df = df.merge(photo_mappings, on='photo')
new_cols = ['id', 'choiceNum', 'candNum', 'college', 'exp', 'job', 'photo', 'gender', 'ethnicity', 'filtered','preference', 'Y' ]
final_df = final_df[new_cols].drop(columns='photo')
final_df
# Out:
#                      id  choiceNum  candNum                       college  \
# 0     R_0GkP9YSiNDMukb7          1        1             Boston University
# 1     R_10Dc7KG5UNa5FTL          2        2             Boston University
# 2     R_10vgeskqNS70Nl2          1        1             Boston University
# 3     R_10vgeskqNS70Nl2          4        1           Stanford University
# 4     R_1C8EXyoBcrNhOeN          3        1                 Virginia Tech
# ...                 ...        ...      ...                           ...
# 4065  R_xlyEl9UuW4Gb5xn          3        1  George Washington University
# 4066  R_xyfhT26F7oOnIcN          4        2             Boston University
# 4067  R_ysb31V3xcF8FkHv          5        2             Boston University
# 4068  R_ZepKbi2sjYj7xzX          1        2                 Virginia Tech
# 4069  R_Zmz2US2dIggx0gp          1        1                 Virginia Tech
#
#       exp                   job  gender ethnicity  filtered  preference  Y
# 0     5.0     Software Engineer    Male     White      True           2  0
# 1     6.0  Sales Representative    Male     White      True           2  1
# 2     6.0  Sales Representative    Male     White      True           1  1
# 3     6.0            Consultant    Male     White      True           1  1
# 4     5.0            Consultant    Male     White      True           2  0
# ...   ...                   ...     ...       ...       ...         ... ..
# 4065  7.0            Consultant  Female       POC     False           1  1
# 4066  5.0          Data Analyst  Female       POC     False           1  0
# 4067  5.0          Data Analyst  Female       POC     False           1  0
# 4068  7.0  Sales Representative  Female       POC     False           2  1
# 4069  6.0  Sales Representative  Female       POC     False           1  1
#
# [4070 rows x 11 columns]

# %% [markdown]
# # Covariates

# %%
cleaned_pre_format = pd.read_csv('cleaned_conj_exp_responses.csv')
cleaned_pre_format.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', '1_Q3', '2_Q3', '3_Q3', '4_Q3',
#        '5_Q3', 'Q61', 'Q30', 'Q30_7_TEXT', 'Q31', 'Q32', 'Q33', 'Q33_7_TEXT',
#        'Unique Survey Code', 'choice1_college1', 'choice1_college2',
#        'choice1_job1', 'choice1_job2', 'choice1_photo1', 'choice1_photo2',
#        'choice2_college1', 'choice2_college2', 'choice2_job1', 'choice2_job2',
#        'choice2_photo1', 'choice2_photo2', 'choice3_college1',
#        'choice3_college2', 'choice3_job1', 'choice3_job2', 'choice3_photo1',
#        'choice3_photo2', 'choice4_college1', 'choice4_college2',
#        'choice4_job1', 'choice4_job2', 'choice4_photo1', 'choice4_photo2',
#        'choice5_college1', 'choice5_college2', 'choice5_job1', 'choice5_job2',
#        'choice5_photo1', 'choice5_photo2', 'choice1_exp1', 'choice1_exp2',
#        'choice2_exp1', 'choice2_exp2', 'choice3_exp1', 'choice3_exp2',
#        'choice4_exp1', 'choice4_exp2', 'choice5_exp1', 'choice5_exp2'],
#       dtype='object')

# %%
covariates = cleaned_pre_format[['ResponseId','Q30', 'Q31', 'Q32', 'Q33']]

# %%
#covariates['Q61'] = covariates['Q61'].str.replace('All of the above', '1,2,3,4,5')
#covariates['Q61'] = covariates['Q61'].str.replace('Q', '')

covariates
# Out:
#             ResponseId                        Q30     Q31              Q32  \
# 0    R_2OOTwdc9qpaeyUM                      White    Male  45-54 years old
# 1    R_1Hdd8hUst2tZXhb                      White    Male  35-44 years old
# 2    R_3Pjfa42q2kQ7vG3                      White    Male  25-34 years old
# 3    R_2X033519KnXqPZN                      White    Male  25-34 years old
# 4    R_2b3suxrXdwXSniG                      White    Male  25-34 years old
# ..                 ...                        ...     ...              ...
# 409  R_3lXpTUN5BVRENUX  Black or African American    Male  25-34 years old
# 410  R_3ltDcAqP8FxgHZf                      White    Male  25-34 years old
# 411  R_3n0gxinPpBmU108                      White  Female  25-34 years old
# 412  R_6ijRBd6GlnVOICJ                      White    Male  25-34 years old
# 413  R_3Oqtne56t2sJDkF                      White    Male  25-34 years old
#
#                       Q33
# 0        Bachelors Degree
# 1        Bachelors Degree
# 2          Masters Degree
# 3        Bachelors Degree
# 4        Bachelors Degree
# ..                    ...
# 409  High School Graduate
# 410        Masters Degree
# 411      Bachelors Degree
# 412  High School Graduate
# 413  High School Graduate
#
# [414 rows x 5 columns]

# %%
#temp = covariates.merge(covariates['Q61'].str.split(',', expand=True), left_index = True, right_index = True)
#temp

# %%
#melted = pd.melt(temp, id_vars = ['ResponseId', 'Q30', 'Q31', 'Q32', 'Q33'], value_vars = [0,1,2,3,4])
#melted

# %%
#melted_keep = melted[~melted['ResponseId'].isin(list(dropped_ids))]

# %%
#melted = melted[melted['value'].notnull()].drop(columns=['variable']).rename(columns={'Q30':'resp_ethnicity', 'Q31':'resp_sex', 'Q32': 'resp_age', 'Q33': 'resp_education'})
#melted = melted.reset_index(drop=True)
#melted['value'] = melted['value'].astype(int)
#melted

# %%
merge_final = final_df.merge(covariates, left_on = ['id'], right_on = ['ResponseId'], how = 'inner').drop(columns=['ResponseId'])
merge_final = merge_final.rename(columns={'Q30':'resp_ethnicity', 'Q31':'resp_sex', 'Q32': 'resp_age', 'Q33': 'resp_education'})

# %%
#merge_final = merge_final.drop(columns= ['ResponseId', 'value'])
#merge_final

# %%
final = merge_final.sort_values(['id', 'choiceNum', 'candNum']).reset_index(drop=True)
final
# Out:
#                      id  choiceNum  candNum                       college  \
# 0     R_0GkP9YSiNDMukb7          1        1             Boston University
# 1     R_0GkP9YSiNDMukb7          1        2           Stanford University
# 2     R_0GkP9YSiNDMukb7          2        1             Boston University
# 3     R_0GkP9YSiNDMukb7          2        2                 Virginia Tech
# 4     R_0GkP9YSiNDMukb7          3        1  George Washington University
# ...                 ...        ...      ...                           ...
# 4065  R_zeaJCDw8vld0P73          3        2  George Washington University
# 4066  R_zeaJCDw8vld0P73          4        1                 Virginia Tech
# 4067  R_zeaJCDw8vld0P73          4        2                 Virginia Tech
# 4068  R_zeaJCDw8vld0P73          5        1  George Washington University
# 4069  R_zeaJCDw8vld0P73          5        2             Boston University
#
#       exp                   job  gender ethnicity  filtered  preference  Y  \
# 0     5.0     Software Engineer    Male     White      True           2  0
# 1     7.0  Sales Representative  Female     White      True           2  1
# 2     7.0  Sales Representative    Male       POC     False           1  1
# 3     6.0  Sales Representative    Male       POC      True           1  0
# 4     7.0     Software Engineer    Male     White     False           1  1
# ...   ...                   ...     ...       ...       ...         ... ..
# 4065  7.0  Sales Representative    Male       POC      True           1  0
# 4066  6.0            Consultant    Male     White     False           2  0
# 4067  7.0  Sales Representative    Male     White      True           2  1
# 4068  7.0          Data Analyst    Male       POC     False           1  1
# 4069  6.0            Consultant    Male       POC      True           1  0
#
#                  resp_ethnicity resp_sex         resp_age  \
# 0     Black or African American     Male  35-44 years old
# 1     Black or African American     Male  35-44 years old
# 2     Black or African American     Male  35-44 years old
# 3     Black or African American     Male  35-44 years old
# 4     Black or African American     Male  35-44 years old
# ...                         ...      ...              ...
# 4065                      White     Male  35-44 years old
# 4066                      White     Male  35-44 years old
# 4067                      White     Male  35-44 years old
# 4068                      White     Male  35-44 years old
# 4069                      White     Male  35-44 years old
#
#             resp_education
# 0         Bachelors Degree
# 1         Bachelors Degree
# 2         Bachelors Degree
# 3         Bachelors Degree
# 4         Bachelors Degree
# ...                    ...
# 4065  High School Graduate
# 4066  High School Graduate
# 4067  High School Graduate
# 4068  High School Graduate
# 4069  High School Graduate
#
# [4070 rows x 15 columns]

# %%
#college
final['college_binary'] = '1-50'
final.loc[final['college'].isin(['Virginia Tech', 'George Washington University', 'University of San Diego' ]), 'college_binary'] = '50-100'

# %%
#jobs
final['job_binary'] = 'front-facing'
final.loc[final['job'].isin(['Software Engineer', 'Data Analyst']), 'job_binary'] = 'back-facing'

# %%
#final.to_csv('final_dataset_no_drop.csv', index=False)

# %%
pd.read_csv('final_dataset_no_drop.csv')
# Out:
#                      id  choiceNum  candNum                       college  \
# 0     R_0GkP9YSiNDMukb7          1        1             Boston University
# 1     R_0GkP9YSiNDMukb7          1        2           Stanford University
# 2     R_0GkP9YSiNDMukb7          2        1             Boston University
# 3     R_0GkP9YSiNDMukb7          2        2                 Virginia Tech
# 4     R_0GkP9YSiNDMukb7          3        1  George Washington University
# ...                 ...        ...      ...                           ...
# 4065  R_zeaJCDw8vld0P73          3        2  George Washington University
# 4066  R_zeaJCDw8vld0P73          4        1                 Virginia Tech
# 4067  R_zeaJCDw8vld0P73          4        2                 Virginia Tech
# 4068  R_zeaJCDw8vld0P73          5        1  George Washington University
# 4069  R_zeaJCDw8vld0P73          5        2             Boston University
#
#       exp                   job  gender ethnicity  filtered  preference  Y  \
# 0     5.0     Software Engineer    Male     White      True           2  0
# 1     7.0  Sales Representative  Female     White      True           2  1
# 2     7.0  Sales Representative    Male       POC     False           1  1
# 3     6.0  Sales Representative    Male       POC      True           1  0
# 4     7.0     Software Engineer    Male     White     False           1  1
# ...   ...                   ...     ...       ...       ...         ... ..
# 4065  7.0  Sales Representative    Male       POC      True           1  0
# 4066  6.0            Consultant    Male     White     False           2  0
# 4067  7.0  Sales Representative    Male     White      True           2  1
# 4068  7.0          Data Analyst    Male       POC     False           1  1
# 4069  6.0            Consultant    Male       POC      True           1  0
#
#                             Q30   Q31              Q32                   Q33  \
# 0     Black or African American  Male  35-44 years old      Bachelors Degree
# 1     Black or African American  Male  35-44 years old      Bachelors Degree
# 2     Black or African American  Male  35-44 years old      Bachelors Degree
# 3     Black or African American  Male  35-44 years old      Bachelors Degree
# 4     Black or African American  Male  35-44 years old      Bachelors Degree
# ...                         ...   ...              ...                   ...
# 4065                      White  Male  35-44 years old  High School Graduate
# 4066                      White  Male  35-44 years old  High School Graduate
# 4067                      White  Male  35-44 years old  High School Graduate
# 4068                      White  Male  35-44 years old  High School Graduate
# 4069                      White  Male  35-44 years old  High School Graduate
#
#      college_binary    job_binary
# 0              1-50   back-facing
# 1              1-50  front-facing
# 2              1-50  front-facing
# 3            50-100  front-facing
# 4            50-100   back-facing
# ...             ...           ...
# 4065         50-100  front-facing
# 4066         50-100  front-facing
# 4067         50-100  front-facing
# 4068         50-100   back-facing
# 4069           1-50  front-facing
#
# [4070 rows x 17 columns]
